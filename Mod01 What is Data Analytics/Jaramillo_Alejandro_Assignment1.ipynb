# %% [markdown]
# # Assignment 1
# Here we are -- Data Analytics time! WoOooooOOoOoo!
# ---
# ### Instructions
#
# Type `pip install pandas` in a teminal to ensure you have the package installed.
#
# 1. Using what we went over in class during the Jupyter tutorial, load in the data found in the **Income Data.csv** file
#     - Create a dataframe with `pandas`
# 2. Print that dataframe using a `print` statement or `df.head()`
#
# Do these steps in the code block below (you may delete the comment if you'd like).

# %%
import pandas as pd, numpy, sklearn, seaborn, statsmodels, matplotlib
print("Environment ready")
# Out:
# Environment ready

# %%
df = pd.read_csv('.\AllPokemon.csv')
print(df)
# Out:
#       Number        Name    Type1   Type2  Total   HP  Atk  Def  SpAtk  SpDef  \
# 0          1   Bulbasaur    Grass  Poison    318   45   49   49     65     65
# 1          2     Ivysaur    Grass  Poison    405   60   62   63     80     80
# 2          3    Venusaur    Grass  Poison    525   80   82   83    100    100
# 3          4  Charmander     Fire            309   39   52   43     60     50
# 4          5  Charmeleon     Fire            405   58   64   58     80     65
# ...      ...         ...      ...     ...    ...  ...  ...  ...    ...    ...
# 1040     896   Glastrier      Ice            580  100  145  130     65    110
# 1041     897   Spectrier    Ghost            580  100   65   60    145     80
# 1042     898     Calyrex  Psychic   Grass    500  100   80   80     80     80
# 1043     898     Calyrex  Psychic     Ice    680  100  165  150     85    130
# 1044     898     Calyrex  Psychic   Ghost    680  100   85   80    165    100
#
#       Spd  Gen
# 0      45    1
# 1      60    1
# 2      80    1
# 3      65    1
# 4      80    1
# ...   ...  ...
# 1040   30    8
# 1041  130    8
# 1042   80    8
# 1043   50    8
# 1044  150    8
#
# [1045 rows x 12 columns]
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# <>:1: SyntaxWarning: invalid escape sequence '\A'
# C:\Users\alejo\AppData\Local\Temp\ipykernel_9192\3403735845.py:1: SyntaxWarning: invalid escape sequence '\A'
#   df = pd.read_csv('.\AllPokemon.csv')

# %% [markdown]
# 3. What's one thing you're proud of yourself for this week, and what's your biggest phobia?

# %% [markdown]
# - I'm proud that I was on time to all my classes
# - My biggest phobia is claustrophobia

# %% [markdown]
# 4. Submit this `Jupyter` file to D2L, renamed as **Last_First_Assignment1.ipynb**
#     - Replace '**Last**' and '**First**' with your name
